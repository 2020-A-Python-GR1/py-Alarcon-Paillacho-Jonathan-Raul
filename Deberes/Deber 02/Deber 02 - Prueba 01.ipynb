# %%
import matplotlib.pyplot as plt
# comando de Jupyter para que las imagenes se muestren automaticamente 
# %matplotlib inline

#tambien importamos numpy ya que lo usamos para crear y manipular matrices
import numpy as np
from skimage import io
from PIL import Image

# %%
imagen_color = io.imread("deadpool.png")
plt.imshow(imagen_color)
print("Dimensiones de la imagen:")
print(imagen_color.shape)
# Out:
# Dimensiones de la imagen:
# (630, 630, 4)

# %%
arreglo = np.array(imagen_color)

# %%
corte_fil_col = arreglo[:315, :315]
#np.append(corte_fil_col,[255,255,255,255])
corte_fil_col.shape
plt.imshow(corte_fil_col)

# %%
corte_fil_col2 = arreglo[0:315,315:630]
corte_fil_col2.shape
plt.imshow(corte_fil_col2)

# %%
corte_fil_col3 = arreglo[315:630,0:315]
corte_fil_col3.shape
plt.imshow(corte_fil_col3)

# %%
corte_fil_col4 = arreglo[315:630,315:630]
corte_fil_col4.shape
plt.imshow(corte_fil_col4)

# %%
past_fil_col = np.concatenate([corte_fil_col,corte_fil_col2],axis=1)#.reshape(630,630,4)
past_fil_col2 = np.concatenate([corte_fil_col3,corte_fil_col4],axis=1)#.reshape(630,630,4)
#print(past_fil_col.flatten().shape)
#print(arreglo.flatten().shape)
plt.imshow(past_fil_col)
plt.show()

plt.imshow(past_fil_col2)
plt.show()

# %%
u_fil_col = np.append(past_fil_col,past_fil_col2)
#print(u_fil_col.flatten().shape)
u_fil_col1 = u_fil_col.reshape(630, 630, 4)
u_fil_col1.shape
plt.imshow(u_fil_col1)
plt.show()

# %%
#********************************************PRUEBA ****************************************************

past_fil_col = np.concatenate([corte_fil_col4,corte_fil_col],axis=1)#.reshape(630,630,4)
past_fil_col2 = np.concatenate([corte_fil_col3,corte_fil_col2],axis=1)#.reshape(630,630,4)
#print(past_fil_col.flatten().shape)
#print(arreglo.flatten().shape)
plt.imshow(past_fil_col)
plt.show()

plt.imshow(past_fil_col2)
plt.show()

# %%
u_fil_col = np.append(past_fil_col,past_fil_col2)
#print(u_fil_col.flatten().shape)
u_fil_col1 = u_fil_col.reshape(630, 630, 4)
u_fil_col1.shape
plt.imshow(u_fil_col1)
plt.show()

# %%
matriz = [corte_fil_col,corte_fil_col2]
matriz.append(corte_fil_col3)
plt.imshow(matriz[2])

# %%
#********************************************************PRUEBA *************************************************
cor1 = arreglo[0:210]
plt.imshow(cor1)
plt.show()
cor2 = arreglo[210:420]
#plt.imshow(cor2)
cor3 = arreglo[420:630]
#plt.imshow(cor3)
cor_1 = cor1[:, :210]
plt.imshow(cor_1)
plt.show()

cor_2 = cor1[:,210:420]
plt.imshow(cor_2)
plt.show()
#im_prueba = Image.fromarray(cor2)
#im_prueba.save(".png")
#io.imsave("corte2.png",cor_2)

cor_3 = cor1[:,420:630]
plt.imshow(cor_3)
plt.show()
io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte3.png",cor_3)

uni = np.concatenate([cor_1,cor_2,cor_3],axis=1)
plt.imshow(uni)
plt.show()

# %%
#def pedazos(cortes):
    #Para guardar todos los arreglos 
    matriz = []
    #Variable para obtener un arreglo para que pueda iterar
    #numero_cortes = np.arange(cortes)
    numero_cortes = np.arange(3)
    #630/n, donde n es el numero de division del rompecabezas
    resultado = 210
    contador = 0
    for res in numero_cortes:
        if contador == 0:
            matriz = arreglo[contador:resultado]
        else:
            #arreglo[resultado:resultado+resultado]
            #primero = resultado
            
            #np.append(matriz,[arreglo[primero:primero+primero]])
            np.append(matriz,[arreglo[resultado:resultado+resultado]])
            #segundo = resultado + resultado
            #print(segundo)
        contador = contador + 1
        print(contador)
    print(matriz.shape)
# Out:
#   File "<ipython-input-65-2817f64ddd18>", line 3
#     matriz = []
#     ^
# IndentationError: unexpected indent

# %%
cortesitos = 3
pedazos(cortesitos)
# Out:
# 1
# 2
# 3
# (210, 630, 4)

# %%
plt.imshow(matriz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-9f893683f097> in <module>
# ----> 1 plt.imshow(matriz)
#
# NameError: name 'matriz' is not defined

# %%
matriz = []
    #Variable para obtener un arreglo para que pueda iterar
    #numero_cortes = np.arange(cortes)
numero_cortes = np.arange(3)
    #630/n, donde n es el numero de division del rompecabezas
resultado = 210
contador = 0
for res in numero_cortes:
    if contador == 0:
        matriz = arreglo[contador:resultado]
    else:
            #arreglo[resultado:resultado+resultado]
            #primero = resultado
            
            #np.append(matriz,[arreglo[primero:primero+primero]])
        #peque_div = np.array(arreglo[resultado:resultado+resultado])
        np.append(matriz,peque_div)
        #np.append(matriz,[arreglo[resultado:resultado+resultado]])
            #segundo = resultado + resultado
            #print(segundo)
        contador = contador + 1
        print(contador)

print(matriz.shape)
plt.imshow(matriz)
# Out:
# (210, 630, 4)

# %%
numero = 210

cort1 = arreglo[0:numero]
plt.imshow(cort1)
plt.show()
np.append(cort1,(arreglo[numero:numero+numero]))
plt.imshow(cort1)
plt.show()
cort2 = cort1
print(cort2.shape)
#cort2 = arreglo[numero:numero+numero]
#plt.imshow(cort2)
#plt.show()
# Out:
# (210, 630, 4)

# %%
a = []
print(type(a))
cor1 = arreglo[0:210]
a.append([cor1])
#print(a.shape)
plt.imshow(a[0])
plt.show()
cor2 = arreglo[210:420]
#a = np.append(a,cor2).reshape(420,630,4)
a.append(cor2)
plt.imshow(a)
plt.show()

print(a[5])
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a1649ceaa5ec> in <module>
#       4 a.append([cor1])
#       5 #print(a.shape)
# ----> 6 plt.imshow(a[0])
#       7 plt.show()
#       8 cor2 = arreglo[210:420]
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
def cortes():
    if numero_cortes == 2:
        corte_1 =
