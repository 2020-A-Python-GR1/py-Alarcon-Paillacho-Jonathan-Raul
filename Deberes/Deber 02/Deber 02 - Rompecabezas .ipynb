# %%
import matplotlib.pyplot as plt
# comando de Jupyter para que las imagenes se muestren automaticamente 
# %matplotlib inline
import numpy as np
from skimage import io
import random

# %%
imagen_color = io.imread("deadpool.png")
plt.imshow(imagen_color)
print("Dimensiones de la imagen:")
print(imagen_color.shape)
arreglo = np.array(imagen_color)
# Out:
# Dimensiones de la imagen:
# (630, 630, 4)

# %%
def cortes(numero_cortes):
    if numero_cortes == 2:
        corte_1 = arreglo[:315, :315]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte1.png",corte_1)
        corte_2 = arreglo[0:315,315:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte2.png",corte_2)
        corte_3 = arreglo[315:630,0:315]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte3.png",corte_3)
        corte_4 = arreglo[315:630,315:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte4.png",corte_4)
        unir_1 = np.concatenate([corte_1,corte_2],axis=1)
        unir_2 = np.concatenate([corte_3,corte_4],axis=1)
        union_total = np.append(unir_1,unir_2).reshape(630, 630, 4)
        print("CORTE DE IMAGEN COMPLETADO CORRECTAMENTE\n")
        #plt.imshow(union_total)
        #plt.show()
    elif numero_cortes == 3:
        corte_1 = arreglo[:210, :210]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte1.png",corte_1)
        corte_2 = arreglo[:210,210:420]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte2.png",corte_2)
        corte_3 = arreglo[:210,420:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte3.png",corte_3)
        corte_4 = arreglo[210:420, :210]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte4.png",corte_4)
        corte_5 = arreglo[210:420,210:420]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte5.png",corte_5)
        corte_6 = arreglo[210:420,420:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte6.png",corte_6)
        corte_7 = arreglo[420:630, :210]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte7.png",corte_7)
        corte_8 = arreglo[420:630,210:420]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte8.png",corte_8)
        corte_9 = arreglo[420:630,420:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte9.png",corte_9)
        unir_1 = np.concatenate([corte_7,corte_3,corte_8],axis=1)
        unir_2 = np.concatenate([corte_6,corte_5,corte_4],axis=1)
        unir_3 = np.concatenate([corte_2,corte_1,corte_9],axis=1)
        union_total = np.append([unir_1,unir_2],unir_3).reshape(630, 630, 4)
        print("CORTE DE IMAGEN COMPLETADO CORRECTAMENTE\n")
        #plt.imshow(union_total)
        #plt.show()
    elif numero_cortes == 4:
        corte_1 = arreglo[:157, :157]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte1.png",corte_1)
        corte_2 = arreglo[:157,156:314]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte2.png",corte_2)
        corte_3 = arreglo[:157,315:472]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte3.png",corte_3)
        corte_4 = arreglo[:157,473:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte4.png",corte_4)
        corte_5 = arreglo[156:314, :157]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte5.png",corte_5)
        corte_6 = arreglo[156:314,156:314]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte6.png",corte_6)
        corte_7 = arreglo[156:314,315:472]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte7.png",corte_7)
        corte_8 = arreglo[156:314,473:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte8.png",corte_8)
        corte_9 = arreglo[315:472, :157]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte9.png",corte_9)
        corte_10 = arreglo[315:472,156:314]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte10.png",corte_10)
        corte_11 = arreglo[315:472,315:472]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte11.png",corte_11)
        corte_12 = arreglo[315:472,473:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte12.png",corte_12)
        corte_13 = arreglo[473:630, :157]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte13.png",corte_13)
        corte_14 = arreglo[473:630,156:314]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte14.png",corte_14)
        corte_15 = arreglo[473:630,315:472]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte15.png",corte_15)
        corte_16 = arreglo[473:630,473:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte16.png",corte_16)
        unir_1 = np.concatenate([corte_1,corte_2,corte_3,corte_4],axis=1)
        unir_2 = np.concatenate([corte_5,corte_6,corte_7,corte_8],axis=1)
        unir_3 = np.concatenate([corte_9,corte_10,corte_11,corte_12],axis=1)
        unir_4 = np.concatenate([corte_13,corte_14,corte_15,corte_16],axis=1)
        union_primero = np.append(unir_1,unir_2).reshape(315, 629, 4)
        union_segundo = np.append(unir_3,unir_4).reshape(314, 629, 4)
        union_total = np.append(union_primero,union_segundo).reshape(629, 629, 4)
        print("CORTE DE IMAGEN COMPLETADO CORRECTAMENTE\n")
        #plt.imshow(union_total)
        #plt.show()
    elif numero_cortes == 5:
        corte_1 = arreglo[:126, :126]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte1.png",corte_1)
        corte_2 = arreglo[:126,126:252]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte2.png",corte_2)
        corte_3 = arreglo[:126,252:378]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte3.png",corte_3)
        corte_4 = arreglo[:126,378:504]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte4.png",corte_4)
        corte_5 = arreglo[:126,504:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte5.png",corte_5)
        corte_6 = arreglo[126:252, :126]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte6.png",corte_6)
        corte_7 = arreglo[126:252,126:252]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte7.png",corte_7)
        corte_8 = arreglo[126:252,252:378]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte8.png",corte_8)
        corte_9 = arreglo[126:252,378:504]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte9.png",corte_9)
        corte_10 = arreglo[126:252,504:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte10.png",corte_10)
        corte_11 = arreglo[252:378, :126]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte11.png",corte_11)
        corte_12 = arreglo[252:378,126:252]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte12.png",corte_12)
        corte_13 = arreglo[252:378,252:378]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte13.png",corte_13)
        corte_14 = arreglo[252:378,378:504]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte14.png",corte_14)
        corte_15 = arreglo[252:378,504:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte15.png",corte_15)
        corte_16 = arreglo[378:504, :126]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte16.png",corte_16)
        corte_17 = arreglo[378:504,126:252]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte17.png",corte_17)
        corte_18 = arreglo[378:504,252:378]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte18.png",corte_18)
        corte_19 = arreglo[378:504,378:504]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte19.png",corte_19)
        corte_20 = arreglo[378:504,504:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte20.png",corte_20)
        corte_21 = arreglo[504:630, :126]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte21.png",corte_21)
        corte_22 = arreglo[504:630,126:252]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte22.png",corte_22)
        corte_23 = arreglo[504:630,252:378]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte23.png",corte_23)
        corte_24 = arreglo[504:630,378:504]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte24.png",corte_24)
        corte_25 = arreglo[504:630,504:630]
        io.imsave("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte25.png",corte_25)
        unir_1 = np.concatenate([corte_1,corte_2,corte_3,corte_4,corte_5],axis=1)
        unir_2 = np.concatenate([corte_6,corte_7,corte_8,corte_9,corte_10],axis=1)
        unir_3 = np.concatenate([corte_11,corte_12,corte_13,corte_14,corte_15],axis=1)
        unir_4 = np.concatenate([corte_16,corte_17,corte_18,corte_19,corte_20],axis=1)
        unir_5 = np.concatenate([corte_21,corte_22,corte_23,corte_24,corte_25],axis=1)
        union_primero = np.append([unir_1,unir_2,unir_3],[unir_4,unir_5]).reshape(630, 630, 4)
        print("CORTE DE IMAGEN COMPLETADO CORRECTAMENTE\n")
        #union_segundo = np.append(unir_3,unir_4).reshape(314, 629, 4)
        #union_total = np.append(union_primero,union_segundo).reshape(629, 629, 4)
        #plt.imshow(union_primero)
        #plt.show()

# %%
def rompecabeza(numero_cortes):
    imagen_retorno = []
    if numero_cortes == 2:
        
        im1 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte1.png")
        im2 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte2.png")
        im3 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte3.png")
        im4 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos2\\corte4.png")
        arreglo_1 = [im1,im2]
        random.shuffle(arreglo_1)
        unir_par1 = np.concatenate([arreglo_1[0],arreglo_1[1]],axis=1)
        
        arreglo_2 = [im3,im4]
        random.shuffle(arreglo_2)
        unir_par2 = np.concatenate([arreglo_2[0],arreglo_2[1]],axis=1)
        
        union_total_par = np.append(unir_par1,unir_par2).reshape(630, 630, 4)
        imagen_retorno = union_total_par
        plt.imshow(union_total_par)
        plt.show()
        
        
    elif numero_cortes == 3:
        
        im1 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte1.png")
        im2 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte2.png")
        im3 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte3.png")
        im4 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte4.png")
        im5 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte5.png")
        im6 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte6.png")
        im7 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte7.png")
        im8 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte8.png")
        im9 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos3\\corte9.png")
        
        orden_1 = [im1,im2,im3]
        random.shuffle(orden_1)
        unir_1 = np.concatenate([orden_1[0],orden_1[1],orden_1[2]],axis=1)
        
        orden_2 = [im4,im5,im6]
        random.shuffle(orden_2)
        unir_2 = np.concatenate([orden_2[0],orden_2[1],orden_2[2]],axis=1)
       
        orden_3 = [im7,im8,im9]
        #random.shuffle(orden_3)
        unir_3 = np.concatenate([orden_3[0],orden_3[1],orden_3[2]],axis=1)
        
        union_total = np.append([unir_1,unir_2],unir_3).reshape(630, 630, 4)
        imagen_retorno = union_total
        
        plt.imshow(union_total)
        plt.show()
            
        
    elif numero_cortes == 4:
        
        im1 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte1.png")
        im2 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte2.png")
        im3 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte3.png")
        im4 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte4.png")
        im5 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte5.png")
        im6 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte6.png")
        im7 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte7.png")
        im8 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte8.png")
        im9 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte9.png")
        im10 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte10.png")
        im11 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte11.png")
        im12 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte12.png")
        im13 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte13.png")
        im14 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte14.png")
        im15 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte15.png")
        im16 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos4\\corte16.png")
        orden_1 = [im1,im2,im3,im4]
        random.shuffle(orden_1)
        unir_1 = np.concatenate([orden_1[0],orden_1[1],orden_1[2],orden_1[3]],axis=1)
        
        orden_2 = [im5,im6,im7,im8]
        random.shuffle(orden_2)
        unir_2 = np.concatenate([orden_2[0],orden_2[1],orden_2[2],orden_2[3]],axis=1)
        
        orden_3 = [im9,im10,im11,im12]
        random.shuffle(orden_3)
        unir_3 = np.concatenate([orden_3[0],orden_3[1],orden_3[2],orden_3[3]],axis=1)
        
        orden_4 = [im13,im14,im15,im16]
        random.shuffle(orden_4)
        unir_4 = np.concatenate([orden_4[0],orden_4[1],orden_4[2],orden_4[3]],axis=1)
        
        union_primero = np.append(unir_1,unir_2).reshape(315, 629, 4)
        union_segundo = np.append(unir_3,unir_4).reshape(314, 629, 4)
        union_total = np.append(union_primero,union_segundo).reshape(629, 629, 4)
        imagen_retorno = union_total
       
        plt.imshow(union_total)
        plt.show()
        
    elif numero_cortes == 5:
        
        im1 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte1.png")
        im2 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte2.png")
        im3 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte3.png")
        im4 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte4.png")
        im5 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte5.png")
        im6 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte6.png")
        im7 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte7.png")
        im8 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte8.png")
        im9 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte9.png")
        im10 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte10.png")
        im11 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte11.png")
        im12 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte12.png")
        im13 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte13.png")
        im14 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte14.png")
        im15 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte15.png")
        im16 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte16.png")
        im17 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte17.png")
        im18 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte18.png")
        im19 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte19.png")
        im20 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte20.png")
        im21 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte21.png")
        im22 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte22.png")
        im23 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte23.png")
        im24 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte24.png")
        im25 = io.imread("C:\\Users\\Familia\\Documents\\GitHub\\py-Alarcon-Paillacho-Jonathan-Raul\\Deberes\\Deber 02\\Archivos5\\corte25.png")
        orden_1 = [im1,im2,im3,im4,im5]
        random.shuffle(orden_1)
        unir_1 = np.concatenate([orden_1[0],orden_1[1],orden_1[2],orden_1[3],orden_1[4]],axis=1)
        
        orden_2 = [im6,im7,im8,im9,im10]
        random.shuffle(orden_2)
        unir_2 = np.concatenate([orden_2[0],orden_2[1],orden_2[2],orden_2[3],orden_2[4]],axis=1)
        
        orden_3 = [im11,im12,im13,im14,im15]
        random.shuffle(orden_3)
        unir_3 = np.concatenate([orden_3[0],orden_3[1],orden_3[2],orden_3[3],orden_3[4]],axis=1)
        
        orden_4 = [im16,im17,im18,im19,im20]
        random.shuffle(orden_4)
        unir_4 = np.concatenate([orden_4[0],orden_4[1],orden_4[2],orden_4[3],orden_4[4]],axis=1)
        
        orden_5 = [im21,im22,im23,im24,im25]
        random.shuffle(orden_5)
        unir_5 = np.concatenate([orden_5[0],orden_5[1],orden_5[2],orden_5[3],orden_5[4]],axis=1)
        
        union_primero = np.append([unir_1,unir_2,unir_3],[unir_4,unir_5]).reshape(630, 630, 4)
        imagen_retorno = union_total
        plt.imshow(union_primero)
        plt.show()
   
    #Esto es lo que estoy agregando
    if (imagen_retorno == imagen_color).all():
        return print("**************************************FELICIDADES COMPLETÓ EL ROMPECABEZAS****************************")
    else:
        rompecabeza(numero_cortes)
    #return imagen_retorno

# %%
def comprobar(imagen_rompe):
    num_pasos = 0
    if (imagen_rompe == imagen_color).all():
        print("**************************************FELICIDADES COMPLETÓ EL ROMPECABEZAS****************************")
        return num_pasos
    else:
        comprobar(rompecabeza(3))
        num_pasos+=1
    #return num_pasos

# %%
def menu():
    print("***********************************BIENVENIDO AL ROMPECABEZAS DE JONATHAN****************************")
    print("1. Rompecabezas de 2x2")
    print("2. Rompecabezas de 3x3")
    print("3. Rompecabezas de 4x4")
    print("4. Rompecabezas de 5x5")
    eleccion = int(input("Elija una opción -> "))
    if eleccion == 1:
        numero = 2
        cortes(numero)
        eleccion = rompecabeza(numero)
        #comprobar(eleccion)
    elif eleccion == 2:
        numero = 3
        cortes(numero)
        eleccion = rompecabeza(numero)
        #comprobar(eleccion)
    elif eleccion == 3:
        numero = 4
        cortes(numero)
        eleccion = rompecabeza(numero)
        #comprobar(eleccion)
    elif eleccion == 4:
        numero = 5
        cortes(numero)
        eleccion = rompecabeza(numero)
        #comprobar(eleccion)
    else:
        print("Ingresó una opción incorrecta")
        exit()

# %%
menu()
# Out:
# ***********************************BIENVENIDO AL ROMPECABEZAS DE JONATHAN****************************
# 1. Rompecabezas de 2x2
# 2. Rompecabezas de 3x3
# 3. Rompecabezas de 4x4
# 4. Rompecabezas de 5x5
# Elija una opción -> 1
# CORTE DE IMAGEN COMPLETADO CORRECTAMENTE
# **************************************FELICIDADES COMPLETÓ EL ROMPECABEZAS****************************
